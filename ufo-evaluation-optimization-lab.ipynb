# %% [markdown]
# ## UFO Sightings Evaluation and Optimization Lab
#
# The goal of this notebook is to find out if our optimized model hyperparmeters out performs the training of our baseline Linear Learner model. We can also compare things like accurary and see if they differ.
#
# What we plan on accompishling is the following:
# 1. [Create and train our "optimized" model (Linear Learner)](#1.-Create-and-train-our-%22optimized%22-model-(Linear-Learner))
# 1. Compare the results!

# %% [markdown]
# First let's go ahead and import all the needed libraries.

# %%
import pandas as pd
import numpy as np
from datetime import datetime


import boto3
from sagemaker import get_execution_role
import sagemaker

# %%
role = get_execution_role()
bucket='algorithms-lab'

# %% [markdown]
# ---
#
# ### 1. Create and train our "optimized" model (Linear Learner)
#
# Let's evaluate the Linear Learner algorithm with the new optimized hyperparameters. Let's go ahead and get the data that we already stored into S3 as recordIO protobuf data.

# %% [markdown]
# Let's get the recordIO file for the training data that is in S3

# %%
train_file = 'ufo_sightings_train_recordIO_protobuf.data'
training_recordIO_protobuf_location = 's3://{}/algorithms_lab/linearlearner_train/{}'.format(bucket, train_file)
print('The Pipe mode recordIO protobuf training data: {}'.format(training_recordIO_protobuf_location))
# Out:
# The Pipe mode recordIO protobuf training data: s3://algorithms-lab/algorithms_lab/linearlearner_train/ufo_sightings_train_recordIO_protobuf.data

# %% [markdown]
# Let's get the recordIO file for the validation data that is in S3

# %%
validation_file = 'ufo_sightings_validatioin_recordIO_protobuf.data'
validate_recordIO_protobuf_location = 's3://{}/algorithms_lab/linearlearner_validation/{}'.format(bucket, validation_file)
print('The Pipe mode recordIO protobuf validation data: {}'.format(validate_recordIO_protobuf_location))
# Out:
# The Pipe mode recordIO protobuf validation data: s3://algorithms-lab/algorithms_lab/linearlearner_validation/ufo_sightings_validatioin_recordIO_protobuf.data

# %% [markdown]
# ---
#
# Alright we are good to go for the Linear Learner algorithm. Let's get everything we need from the ECR repository to call the Linear Learner algorithm.

# %%
from sagemaker.amazon.amazon_estimator import get_image_uri
import sagemaker

container = get_image_uri(boto3.Session().region_name, 'linear-learner', "1")

# %% [markdown]
# Let's create a job and use the optimzed hyperparamters.

# %%
# Create a training job name
job_name = 'ufo-linear-learner-job-optimized-{}'.format(datetime.now().strftime("%Y%m%d%H%M%S"))
print('Here is the job name {}'.format(job_name))

# Here is where the model-artifact will be stored
output_location = 's3://{}/optimization_evaluation_lab/linearlearner_optimized_output'.format(bucket)
# Out:
# Here is the job name ufo-linear-learner-job-optimized-20190813163756

# %% [markdown]
# Next we can start building out our model by using the SageMaker Python SDK and passing in everything that is required to create a Linear Learner training job.
#
# Here are the [linear learner hyperparameters](https://docs.aws.amazon.com/sagemaker/latest/dg/ll_hyperparameters.html) that we can use within our training job.
#
# After we run this job we can view the results.

# %%
# %%time
sess = sagemaker.Session()

# Setup the LinearLeaner algorithm from the ECR container
linear = sagemaker.estimator.Estimator(container,
                                       role, 
                                       train_instance_count=1, 
                                       train_instance_type='ml.c4.xlarge',
                                       output_path=output_location,
                                       sagemaker_session=sess,
                                       input_mode='Pipe')
# Setup the hyperparameters
linear.set_hyperparameters( feature_dim=22, 
                            predictor_type='multiclass_classifier',
                            num_classes=3,
                            early_stopping_patience=3,
                            early_stopping_tolerance=0.001,
                            epochs=15,
                            l1=0.6854682581436183,
                            learning_rate=0.3845283993921106,
                            loss='auto',
                            mini_batch_size=2157,
                            normalize_data='true',
                            normalize_label='auto',
                            num_models='auto',
                            optimizer='auto',
                            unbias_data='auto',
                            unbias_label='auto',
                            use_bias='false',
                            wd=0.00016191101061184497
                          )


# Launch a training job. This method calls the CreateTrainingJob API call
data_channels = {
    'train': training_recordIO_protobuf_location,
    'validation': validate_recordIO_protobuf_location
}
linear.fit(data_channels, job_name=job_name)
# Out:
# 2019-08-13 16:45:15 Starting - Starting the training job...
# 2019-08-13 16:45:31 Starting - Launching requested ML instances......
# 2019-08-13 16:46:33 Starting - Preparing the instances for training.........
# 2019-08-13 16:48:15 Downloading - Downloading input data
# 2019-08-13 16:48:15 Training - Downloading the training image..
# Docker entrypoint called with argument(s): train
# [08/13/2019 16:48:31 INFO 139922715727680] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [08/13/2019 16:48:31 INFO 139922715727680] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'loss': u'auto', u'wd': u'0.00016191101061184497', u'optimizer': u'auto', u'predictor_type': u'multiclass_classifier', u'unbias_label': u'auto', u'early_stopping_tolerance': u'0.001', u'num_models': u'auto', u'learning_rate': u'0.3845283993921106', u'normalize_data': u'true', u'epochs': u'15', u'normalize_label': u'auto', u'feature_dim': u'22', u'unbias_data': u'auto', u'l1': u'0.6854682581436183', u'mini_batch_size': u'2157', u'use_bias': u'false', u'early_stopping_patience': u'3', u'num_classes': u'3'}
# [08/13/2019 16:48:31 INFO 139922715727680] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'22', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'false', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'0.00016191101061184497', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'0.3845283993921106', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'2157', u'huber_delta': u'1.0', u'num_classes': u'3', u'predictor_type': u'multiclass_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'0.6854682581436183', u'margin': u'1.0'}
# [08/13/2019 16:48:31 WARNING 139922715727680] Loggers have already been setup.
# Process 1 is a worker.
# [08/13/2019 16:48:31 INFO 139922715727680] Using default worker.
# [08/13/2019 16:48:31 INFO 139922715727680] The channel 'train' is in pipe input mode under /opt/ml/input/data/train.
# [08/13/2019 16:48:31 INFO 139922715727680] The channel 'validation' is in pipe input mode under /opt/ml/input/data/validation.
# [2019-08-13 16:48:31.851] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [2019-08-13 16:48:31.886] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 44, "num_examples": 1, "num_bytes": 284724}
# [08/13/2019 16:48:31 INFO 139922715727680] Create Store: local
# [2019-08-13 16:48:32.008] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 121, "num_examples": 5, "num_bytes": 1423620}
# [08/13/2019 16:48:32 INFO 139922715727680] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f41f6eb70d0>
# [08/13/2019 16:48:32 INFO 139922715727680] Scaling model computed with parameters:
#  {'stdev_weight':
# [58.09025     6.231457   39.12195    95.35414     0.38372064  0.27573815
#   0.4209401   0.34139532  0.41539678  0.38660944  0.37910175  0.34423527
#   0.34931552  0.10894189  0.57927424  0.57251203  0.30738103  0.09772564
#   0.10370959  0.23821309  0.3070792   0.24283902]
# <NDArray 22 @cpu(0)>, 'stdev_label': None, 'mean_label': None, 'mean_weight': None}
# [08/13/2019 16:48:32 INFO 139922715727680] nvidia-smi took: 0.0252249240875 secs to identify 0 gpus
# [08/13/2019 16:48:32 INFO 139922715727680] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 6, "sum": 6.0, "min": 6}, "Total Records Seen": {"count": 1, "max": 12942, "sum": 12942.0, "min": 12942}, "Max Records Seen Between Resets": {"count": 1, "max": 10785, "sum": 10785.0, "min": 10785}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1565714912.13446, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1565714912.134426}
#
# [2019-08-13 16:48:32.456] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 3, "duration": 321, "num_examples": 7, "num_bytes": 1904760}
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.6344983521356702, "sum": 0.6344983521356702, "min": 0.6344983521356702}}, "EndTime": 1565714912.45652, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1565714912.456425}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 1.1792100845358136, "sum": 1.1792100845358136, "min": 1.1792100845358136}}, "EndTime": 1565714912.45661, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1565714912.456595}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 1.8891480642904401, "sum": 1.8891480642904401, "min": 1.8891480642904401}}, "EndTime": 1565714912.456656, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1565714912.456645}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.8530050321038697, "sum": 0.8530050321038697, "min": 0.8530050321038697}}, "EndTime": 1565714912.456696, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1565714912.
#early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=multiclass_cross_entropy_objective, value=0.201422005539
# [08/13/2019 16:48:32 INFO 139922715727680] Epoch 0: Loss improved. Updating best model
# [08/13/2019 16:48:32 INFO 139922715727680] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 7, "sum": 7.0, "min": 7}, "Number of Batches Since Last Reset": {"count": 1, "max": 7, "sum": 7.0, "min": 7}, "Number of Records Since Last Reset": {"count": 1, "max": 14430, "sum": 14430.0, "min": 14430}, "Total Batches Seen": {"count": 1, "max": 13, "sum": 13.0, "min": 13}, "Total Records Seen": {"count": 1, "max": 27372, "sum": 27372.0, "min": 27372}, "Max Records Seen Between Resets": {"count": 1, "max": 14430, "sum": 14430.0, "min": 14430}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1565714912.510952, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1565714912.134674}
#
# [08/13/2019 16:48:32 INFO 139922715727680] #throughput_metric: host=algo-1, train throughput=38336.0506724 records/second
#
# 2019-08-13 16:48:39 Uploading - Uploading generated training model
# 2019-08-13 16:48:39 Completed - Training job completed
# [2019-08-13 16:48:32.817] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 306, "num_examples": 7, "num_bytes": 1904760}
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.46169402562122114, "sum": 0.46169402562122114, "min": 0.46169402562122114}}, "EndTime": 1565714912.817985, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1565714912.817757}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.45821722882771454, "sum": 0.45821722882771454, "min": 0.45821722882771454}}, "EndTime": 1565714912.818098, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1565714912.818048}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.8172725606159935, "sum": 0.8172725606159935, "min": 0.8172725606159935}}, "EndTime": 1565714912.818167, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1565714912.818149}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.7054179920661654, "sum": 0.7054179920661654, "min": 0.7054179920661654}}, "EndTime": 1565714912.818232, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1565714912.818214}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.5205303458006152, "sum": 0.5205303458006152, "min": 0.5205303458006152}}, "EndTime": 1565714912.818284, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1565714912.818268}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.28621131591608234, "sum": 0.28621131591608234, "min": 0.28621131591608234}}, "EndTime": 1565714912.818345, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1565714912.818328}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.7122137204993915, "sum": 0.7122137204993915, "min": 0.7122137204993915}}, "EndTime": 1565714912.818405, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1565714912.818388}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.2972246528758717, "sum": 0.2972246528758717, "min": 0.2972246528758717}}, "EndTime": 1565714912.81848, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1565714912.818459}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 1.2540467883755408, "sum": 1.2540467883755408, "min": 1.2540467883755408}}, "EndTime": 1565714912.818543, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1565714912.818524}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 1.2912076249444637, "sum": 1.2912076249444637, "min": 1.2912076249444637}}, "EndTime": 1565714912.818601, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1565714912.818585}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.2597976658632022, "sum": 0.2597976658632022, "min": 0.2597976658632022}}, "EndTime": 1565714912.81866, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1565714912.818642}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 1.2017268223733775, "sum": 1.2017268223733775, "min": 1.2017268223733775}}, "EndTime": 1565714912.818718, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1565714912.818701}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.5273513381290686, "sum": 0.5273513381290686, "min": 0.5273513381290686}}, "EndTime": 1565714912.818779, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1565714912.818762}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.6140033248550021, "sum": 0.6140033248550021, "min": 0.6140033248550021}}, "EndTime": 1565714912.818837, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1565714912.81882}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 1.374203232299635, "sum": 1.374203232299635, "min": 1.374203232299635}}, "EndTime": 1565714912.818894, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1565714912.818877}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.22762376045152774, "sum": 0.22762376045152774, "min": 0.22762376045152774}}, "EndTime": 1565714912.81895, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1565714912.818934}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.22374101761706072, "sum": 0.22374101761706072, "min": 0.22374101761706072}}, "EndTime": 1565714912.819019, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1565714912.819001}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.28375721405175497, "sum": 0.28375721405175497, "min": 0.28375721405175497}}, "EndTime": 1565714912.819074, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1565714912.819058}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 1.2777222226749634, "sum": 1.2777222226749634, "min": 1.2777222226749634}}, "EndTime": 1565714912.819133, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1565714912.819115}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 1.0699557023040296, "sum": 1.0699557023040296, "min": 1.0699557023040296}}, "EndTime": 1565714912.819193, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1565714912.819177}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 1

#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 1.1358007096464326, "sum": 1.1358007096464326, "min": 1.1358007096464326}}, "EndTime": 1565714912.8706, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1565714912.870584}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.8078658033479625, "sum": 0.8078658033479625, "min": 0.8078658033479625}}, "EndTime": 1565714912.870662, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1565714912.870645}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.977481641946912, "sum": 0.977481641946912, "min": 0.977481641946912}}, "EndTime": 1565714912.870723, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1565714912.870705}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 1.0392514232586012, "sum": 1.0392514232586012, "min": 1.0392514232586012}}, "EndTime": 1565714912.870785, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1565714912.870767}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.9042034461144599, "sum": 0.9042034461144599, "min": 0.9042034461144599}}, "EndTime": 1565714912.870848, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1565714912.870831}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.26865966590326246, "sum": 0.26865966590326246, "min": 0.26865966590326246}}, "EndTime": 1565714912.870908, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1565714912.870891}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.8554196602465807, "sum": 0.8554196602465807, "min": 0.8554196602465807}}, "EndTime": 1565714912.870971, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1565714912.870954}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.18332817994196807, "sum": 0.18332817994196807, "min": 0.18332817994196807}}, "EndTime": 1565714912.871034, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1565714912.871017}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.5535614306282607, "sum": 0.5535614306282607, "min": 0.5535614306282607}}, "EndTime": 1565714912.871095, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1565714912.871079}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.185656380263413, "sum": 0.185656380263413, "min": 0.185656380263413}}, "EndTime": 1565714912.871156, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1565714912.871138}
#
# [08/13/2019 16:48:32 INFO 139922715727680] #quality_metric: host=algo-1, epoch=1, validation multiclass_cross_entropy_objective <loss>=0.34963746563
# [08/13/2019 16:48:32 INFO 139922715727680] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=multiclass_cross_entropy_objective, value=0.183328179942
# [08/13/2019 16:48:32 INFO 139922715727680] Epoch 1: Loss improved. Updating best model
# [08/13/2019 16:48:32 INFO 139922715727680] #progress_metric: host=algo-1, completed 13 % of epochs
# ...
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.2211583066329284, "sum": 0.2211583066329284, "min": 0.2211583066329284}}, "EndTime": 1565714915.033245, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1565714915.033236}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.20250267673728825, "sum": 0.20250267673728825, "min": 0.20250267673728825}}, "EndTime": 1565714915.033282, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1565714915.033272}
#
# [08/13/2019 16:48:35 INFO 139922715727680] #quality_metric: host=algo-1, epoch=7, train multiclass_cross_entropy_objective <loss>=0.216186853561
# [2019-08-13 16:48:35.077] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 23, "duration": 33, "num_examples": 1, "num_bytes": 234036}
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.185629460076054, "sum": 0.185629460076054, "min": 0.185629460076054}}, "EndTime": 1565714915.081546, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1565714915.081493}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.24212710170240234, "sum": 0.24212710170240234, "min": 0.24212710170240234}}, "EndTime": 1565714915.081627, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1565714915.081607}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.6865341091855259, "sum": 0.6865341091855259, "min": 0.6865341091855259}}, "EndTime": 1565714915.081694, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1565714915.081675}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.2094958069226329, "sum": 0.2094958069226329, "min": 0.2094958069226329}}, "EndTime": 1565714915.081738, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1565714915.081727}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.45764848652090384, "sum": 0.45764848652090384, "min": 0.45764848652090384}}, "EndTime": 1565714915.081778, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1565714915.081764}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.22453813289291633, "sum": 0.22453813289291633, "min": 0.22453813289291633}}, "EndTime": 1565714915.081834, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1565714915.081817}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.6237656646573604, "sum": 0.6237656646573604, "min": 0.6237656646573604}}, "EndTime": 1565714915.081895, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1565714915.081877}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.39840166379150804, "sum": 0.39840166379150804, "min": 0.39840166379150804}}, "EndTime": 1565714915.081955, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1565714915.081937}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 1.4616889243601945, "sum": 1.4616889243601945, "min": 1.4616889243601945}}, "EndTime": 1565714915.082017, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1565714915.081999}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 1.0279423282836295, "sum": 1.0279423282836295, "min": 1.0279423282836295}}, "EndTime": 1565714915.082103, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1565714915.
#early_stopping_criteria_metric: host=algo-1, epoch=7, criteria=multiclass_cross_entropy_objective, value=0.173458092911
# [2019-08-13 16:48:35.168] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 28, "duration": 27, "num_examples": 1, "num_bytes": 234036}
# [08/13/2019 16:48:35 INFO 139922715727680] #validation_score (algo-1) : ('multiclass_cross_entropy_objective', 0.17245128823079703)
# [08/13/2019 16:48:35 INFO 139922715727680] #validation_score (algo-1) : ('multiclass_accuracy', 0.9554427523970671)
# [08/13/2019 16:48:35 INFO 139922715727680] #validation_score (algo-1) : ('multiclass_top_k_accuracy_3', 1.0)
# [08/13/2019 16:48:35 INFO 139922715727680] #validation_score (algo-1) : ('dcg', 0.9825213626489354)
# [08/13/2019 16:48:35 INFO 139922715727680] #validation_score (algo-1) : ('macro_recall', 0.9473136)
# [08/13/2019 16:48:35 INFO 139922715727680] #validation_score (algo-1) : ('macro_precision', 0.91764385)
# [08/13/2019 16:48:35 INFO 139922715727680] #validation_score (algo-1) : ('macro_f_1.000', 0.93166703)
# [08/13/2019 16:48:35 INFO 139922715727680] #quality_metric: host=algo-1, validation multiclass_cross_entropy_objective <loss>=0.172451288231
# [08/13/2019 16:48:35 INFO 139922715727680] #quality_metric: host=algo-1, validation multiclass_accuracy <score>=0.955442752397
# [08/13/2019 16:48:35 INFO 139922715727680] #quality_metric: host=algo-1, validation multiclass_top_k_accuracy_3 <score>=1.0
# [08/13/2019 16:48:35 INFO 139922715727680] #quality_metric: host=algo-1, validation dcg <score>=0.982521362649
# [08/13/2019 16:48:35 INFO 139922715727680] #quality_metric: host=algo-1, validation macro_recall <score>=0.947313606739
# [08/13/2019 16:48:35 INFO 139922715727680] #quality_metric: host=algo-1, validation macro_precision <score>=0.917643845081
# [08/13/2019 16:48:35 INFO 139922715727680] #quality_metric: host=algo-1, validation macro_f_1.000 <score>=0.931667029858
# [08/13/2019 16:48:35 INFO 139922715727680] Best model found for hyperparameters: {"lr_scheduler_step": 11, "wd": 0.002812240736971193, "optimizer": "adam", "lr_scheduler_factor": 0.9843474924627743, "l1": 0.04916631319336727, "learning_rate": 0.052282518254785845, "lr_scheduler_minimum_lr": 3.072407411146648e-06}
# [08/13/2019 16:48:35 INFO 139922715727680] Saved checkpoint to "/tmp/tmpoHE_li/mx-mod-0000.params"
# [08/13/2019 16:48:35 INFO 139922715727680] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 3430.981159210205, "sum": 3430.981159210205, "min": 3430.981159210205}, "finalize.time": {"count": 1, "max": 103.09696197509766, "sum": 103.09696197509766, "min": 103.09696197509766}, "initialize.time": {"count": 1, "max": 271.62790298461914, "sum": 271.62790298461914, "min": 271.62790298461914}, "check_early_stopping.time": {"count": 9, "max": 0.9171962738037109, "sum": 4.112958908081055, "min": 0.18715858459472656}, "setuptime": {"count": 1, "max": 24.299144744873047, "sum": 24.299144744873047, "min": 24.299144744873047}, "update.time": {"count": 8, "max": 382.0931911468506, "sum": 2945.9710121154785, "min": 344.0887928009033}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1565714915.197403, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1565714911.841598}
#
# Billable seconds: 30
# CPU times: user 534 ms, sys: 48.3 ms, total: 582 ms
# Wall time: 3min 42s

# %% [markdown]
# Now we can compare the amount of time billed and the accuracy compared to our baseline model.
